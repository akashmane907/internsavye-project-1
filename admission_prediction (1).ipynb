# %% [markdown]
# # Admission Prediction
# The aim of this analysis is to predict chance of admission in a college using various scores

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
data = files.upload ()
# Out:
#      <input type="file" id="files-f5048e77-8f66-4052-a09d-37b5ce7ba49c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5048e77-8f66-4052-a09d-37b5ce7ba49c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Admission_Predict_Ver1.1.csv')

# %%
print(df.head())
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
print(df.describe())
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
print(df.dtypes)
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
print('null values:)')
df.isnull().sum()
# Out:
# null values:)
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.groupby('University Rating').mean()
# Out:
#                    Serial No.   GRE Score  TOEFL Score       SOP      LOR   \
# University Rating
# 1                  281.558824  304.911765   100.205882  1.941176  2.426471
# 2                  249.555556  309.134921   103.444444  2.682540  2.956349
# 3                  247.574074  315.030864   106.314815  3.308642  3.401235
# 4                  275.809524  323.304762   110.961905  4.000000  3.947619
# 5                  207.753425  327.890411   113.438356  4.479452  4.404110
#
#                        CGPA  Research  Chance of Admit
# University Rating
# 1                  7.798529  0.294118          0.562059
# 2                  8.177778  0.293651          0.626111
# 3                  8.500123  0.537037          0.702901
# 4                  8.936667  0.780952          0.801619
# 5                  9.278082  0.876712          0.888082
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# has we can see GRE score ,TOEFL score ,SOP are related to Rating of Colleges

# %%
plt.subplots(figsize=(20,4))
sns.barplot(x="GRE Score",y="Chance of Admit ",data=df)
# Out:
# <Axes: xlabel='GRE Score', ylabel='Chance of Admit '>

# %%
plt.subplots(figsize=(25,5))
sns.barplot(x="TOEFL Score",y="Chance of Admit ",data=df)
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Chance of Admit '>

# %% [markdown]
# Here we can see that Chance of admission is more with higher TOEFL Score

# %%
plt.subplots(figsize=(90,11))
sns.barplot(x="CGPA",y="Chance of Admit ",data=df)
# Out:
# <Axes: xlabel='CGPA', ylabel='Chance of Admit '>

# %% [markdown]
# With increase in CGPA there is better chance to get Admitted in collage

# %%
plt.subplots(figsize=(10,5))
sns.barplot(x="SOP",y="Chance of Admit ",data=df)
# Out:
# <Axes: xlabel='SOP', ylabel='Chance of Admit '>

# %% [markdown]
# Chance of admission increases with increase in SOP

# %%
plt.subplots(figsize=(8,3))
sns.barplot(x="Research",y="Chance of Admit ",data=df)
# Out:
# <Axes: xlabel='Research', ylabel='Chance of Admit '>

# %%
X=df.iloc[:,:7]
y=df["Chance of Admit "]

# %%
print(X.shape)
print(y.shape)
X.head()
# Out:
# (500, 7)
# (500,)
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21

# %% [markdown]
# students who has done research has slightly better chance of admission

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=50)

# %%
from sklearn.linear_model import LinearRegression
#Linear Regression
Linear=LinearRegression()
Linear.fit(X_train,y_train)
y_pred=Linear.predict(X_test)
y_pred
# Out:
# array([0.62340204, 0.58524434, 0.64918847, 0.53197239, 0.52256199,
#        0.77262958, 0.91075027, 0.64439212, 0.55905941, 0.56829616,
#        0.94781964, 0.92827355, 0.79053606, 0.73824407, 0.79822944,
#        0.66445966, 0.77722628, 0.88750967, 0.67354417, 0.80328974,
#        0.68131038, 0.64325103, 0.65350318, 0.62733979, 0.65592314,
#        0.70629063, 0.73536169, 0.83672736, 0.68970009, 0.64195202,
#        0.99126339, 0.68596425, 0.88069095, 0.90845059, 0.53376767,
#        0.71557904, 0.98155699, 0.71950105, 0.93832444, 0.47217492,
#        0.94381715, 0.872638  , 0.69599205, 0.70865625, 0.77822867,
#        0.65443226, 0.74376175, 0.8133684 , 0.5267657 , 0.85315358,
#        0.8463226 , 0.80704977, 0.59791199, 0.6870531 , 0.55675412,
#        0.78057175, 0.75033578, 0.97112279, 0.44232004, 0.57257047,
#        0.62266796, 0.94591388, 0.81759535, 0.89324122, 0.66256311,
#        0.6532196 , 0.71187755, 0.73126216, 0.57038978, 0.95213082,
# ...

# %%
from sklearn.metrics import mean_absolute_error,r2_score
print("R2 score of the model is ",r2_score(y_pred,y_test))
print("mean_absolute_error  of the model is ",mean_absolute_error(y_pred,y_test))
# Out:
# R2 score of the model is  0.8206370611817029
# mean_absolute_error  of the model is  0.04008979163185059
